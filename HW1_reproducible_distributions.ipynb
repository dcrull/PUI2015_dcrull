# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
import numpy as np
np.random.seed(32)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
np.random.seed(32)
first_array = np.random.randn(100,2)
print first_array
first_std = np.std(first_array)
first_mean = np.mean(first_array)
print "Array mean is: {:.4f}, and standard deviation is: {:.4f}".format(first_mean,first_std)
# Out:
# [[ -3.48894451e-01   9.83703433e-01]
#  [  5.80922831e-01   7.02844409e-02]
#  [  7.77532676e-01   5.81958745e-01]
#  [  1.47179053e+00   1.66318101e+00]
#  [ -2.61177121e-01  -6.88676813e-01]
#  [ -6.94923262e-01   1.94042346e+00]
#  [  1.80541519e+00   4.56313852e-01]
#  [ -5.74812040e-01   1.14180503e-01]
#  [  1.51358077e+00   3.51131840e-01]
#  [ -8.89332139e-02   9.16954228e-01]
#  [  5.05645125e-01  -8.15271110e-01]
#  [  3.89150951e-01  -4.24962470e-01]
#  [  3.96231519e-02  -5.27963922e-01]
#  [ -5.10303679e-01  -8.88285149e-01]
#  [  1.08762473e+00   6.73392264e-01]
#  [ -1.06731704e+00   1.21804998e+00]
#  [  3.36371255e+00  -8.32253403e-01]
#  [ -3.40348381e-01  -1.85857154e+00]
#  [  8.23065599e-04   3.51574483e-01]
#  [  1.52150885e+00  -6.80474137e-01]
#  [  9.38057708e-01  -6.81414713e-01]
#  [ -2.01098083e-01  -1.74886440e-02]
#  [ -1.78791213e+00  -8.51740228e-01]
#  [ -1.62830331e+00   9.66997738e-01]
#  [  5.31155943e-02   2.89712932e-01]
#  [  6.24443380e-02  -1.09812873e+00]
#  [  1.30533064e-01  -1.85337064e-01]
#  [ -1.34073473e+00  -3.24019679e-01]
#  [  1.48436338e+00   1.31308828e+00]
#  [ -6.32164014e-01  -3.91573298e-01]
#  [ -2.36849570e+00  -5.90683913e-01]
#  [ -1.71300152e+00  -1.31285141e+00]
#  [  4.53779604e-01  -1.78332529e+00]
#  [  1.42551583e+00  -3.45698608e-01]
#  [  9.98657431e-01   7.25386344e-01]
#  [ -9.28409701e-01  -6.79982736e-01]
#  [ -1.11262844e+00   1.24751610e-02]
#  [ -5.26311356e-01  -6.79530896e-01]
#  [  1.45994761e+00   1.36657358e+00]
#  [  1.70810135e+00   2.39030424e-01]
#  [ -4.59934590e-01   1.15831171e+00]
#  [  2.53673937e-01   2.03742962e-01]
#  [  1.77320156e+00   9.88609277e-01]
# %%
np.random.seed(32)
second_array = 2.5 * np.random.randn(50,2) + (3,2)
second_array
print second_array
second_std = np.std(second_array)
second_mean = np.mean(second_array)
print "Array mean is: {:.4f}, and standard deviation is: {:.4f}".format(second_mean,second_std)
# Out:
# [[  2.12776387   4.45925858]
#  [  4.45230708   2.1757111 ]
#  [  4.94383169   3.45489686]
#  [  6.67947632   6.15795252]
#  [  2.3470572    0.27830797]
#  [  1.26269184   6.85105865]
#  [  7.51353798   3.14078463]
#  [  1.5629699    2.28545126]
#  [  6.78395192   2.8778296 ]
#  [  2.77766697   4.29238557]
#  [  4.26411281  -0.03817777]
#  [  3.97287738   0.93759382]
#  [  3.09905788   0.6800902 ]
#  [  1.7242408   -0.22071287]
#  [  5.71906184   3.68348066]
#  [  0.33170741   5.04512496]
#  [ 11.40928137  -0.08063351]
#  [  2.14912905  -2.64642886]
#  [  3.00205766   2.87893621]
#  [  6.80377212   0.29881466]
#  [  5.34514427   0.29646322]
#  [  2.49725479   1.95627839]
#  [ -1.46978032  -0.12935057]
#  [ -1.07075828   4.41749435]
#  [  3.13278899   2.72428233]
#  [  3.15611084  -0.74532183]
#  [  3.32633266   1.53665734]
#  [ -0.35183682   1.1899508 ]
#  [  6.71090846   5.2827207 ]
#  [  1.41958996   1.02106676]
#  [ -2.92123926   0.52329022]
#  [ -1.28250381  -1.28212852]
#  [  4.13444901  -2.45831324]
#  [  6.56378959   1.13575348]
#  [  5.49664358   3.81346586]
#  [  0.67897575   0.30004316]
#  [  0.2184289    2.0311879 ]
#  [  1.68422161   0.30117276]
#  [  6.64986901   5.41643395]
#  [  7.27025337   2.59757606]
#  [  1.85016353   4.89577928]
#  [  3.63418484   2.50935741]
#  [  7.43300391   4.47152319]
#  [  0.97143204  -1.80814872]
#  [  2.2475138    1.02347243]
#  [  4.17009287   5.78387105]
#  [  4.06160027   2.30586555]
#  [ -0.46911779   0.83239725]
#  [  6.18399157   2.30430404]
#  [ -0.04366054   3.00822025]]
# Array mean is: 2.6592, and standard deviation is: 2.6431

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
import pylab as pl
# %matplotlib inline
x = np.transpose(first_array)
y = np.transpose(second_array)

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
pl.scatter(first_array,x, color="blue", label="Array 1 (Std=1.0041, Mu=0.1029)")
pl.scatter(second_array,y, color="red", label="Array 2 (Std=2.6431, Mu=2.6592)")
pl.legend(loc="upper right")
